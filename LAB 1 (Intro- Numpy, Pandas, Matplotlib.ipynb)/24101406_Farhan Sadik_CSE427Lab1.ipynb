# %% [markdown]
# # NumPy

# %%
import numpy as np

# %% [markdown]
# 1. Create two linear arrays a and b with 20 random elements each ranging from 1 to 100.

# %%
a = np.random.randint(1, 101, 20)
b = np.random.randint(1, 101, 20)

print("A:", a)
print("B:", b)
# Out:
# A: [ 3 19 61 44 88 67  2  4  3 71 85 91 50 30 85 34 54 67 51  5]
# B: [41 25 41 91 73 84 11 38  9 19 22 75 59 21 64 72 31 99 13 83]

# %% [markdown]
# 2. Now change those linear arrays to two 5x4 matrices.

# %%
a = a.reshape(5,4)
b = b.reshape(5,4)

print("MatrixA:\n", a)
print("MatrixB:\n", b)
# Out:
# MatrixA:
#  [[ 3 19 61 44]
#  [88 67  2  4]
#  [ 3 71 85 91]
#  [50 30 85 34]
#  [54 67 51  5]]
# MatrixB:
#  [[41 25 41 91]
#  [73 84 11 38]
#  [ 9 19 22 75]
#  [59 21 64 72]
#  [31 99 13 83]]

# %% [markdown]
# 3. Perform scalar multiplication with matrix a and b.

# %%
scalar = 10
a_scalar = a * scalar
b_scalar = b * scalar

print("A:\n", a_scalar)
print("B:\n", b_scalar)
# Out:
# A:
#  [[ 30 190 610 440]
#  [880 670  20  40]
#  [ 30 710 850 910]
#  [500 300 850 340]
#  [540 670 510  50]]
# B:
#  [[410 250 410 910]
#  [730 840 110 380]
#  [ 90 190 220 750]
#  [590 210 640 720]
#  [310 990 130 830]]

# %% [markdown]
# 4. Now try to modify the matrix b and perform matrix multiplication with a and b to store it in
# c

# %%
b = b.T
c = np.matmul(a,b)

print("Matrix C:\n", c)
# Out:
# Matrix C:
#  [[ 7103  4158  5030  7648  6419]
#  [ 5729 12226  2409  7015  9719]
#  [13664 10576 10071 13660 15780]
#  [ 9379  8397  5440 11468  8447]
#  [ 6435 10321  3256  8217  9385]]

# %% [markdown]
# 5. Print only the column 2, 3 of matrix c. Print the whole matrix using slicing technique.

# %%
print(c[:,1:3])
# Out:
# [[ 4158  5030]
#  [12226  2409]
#  [10576 10071]
#  [ 8397  5440]
#  [10321  3256]]

# %% [markdown]
# 6. Find the largest element in the array, and also the index of that element.

# %%
largest = np.max(c)
index = np.argmax(c)

print("Largest =", largest)
print("Index =", index)
# Out:
# Largest = 15780
# Index = 14

# %% [markdown]
# 7. Convert the matrix c into an one dimensional array keeping the original array
# unchanged.

# %%
modifiedC = c.flatten()

print(modifiedC)
# Out:
# [ 7103  4158  5030  7648  6419  5729 12226  2409  7015  9719 13664 10576
#  10071 13660 15780  9379  8397  5440 11468  8447  6435 10321  3256  8217
#   9385]

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# 1. Read the CSV file as DataFrames.

# %%
loc = "/content/subject_scores.csv"
df = pd.read_csv(loc)

# %% [markdown]
# 2. Show the first few rows of the DataFrame to get an idea of the whole dataset.

# %%
print(df.head())
# Out:
#    Student_ID  Physics  Chemistry  Math  Bilogy
# 0           1     63.0         37  85.0    94.0
# 1           2     52.0         63  34.0    24.0
# 2           3     51.0         25   2.0     7.0
# 3           4     44.0          2   5.0    22.0
# 4           5     50.0         13   1.0    12.0

# %% [markdown]
# 3. Show the summarized details of the dataset.

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  20 non-null     int64
#  1   Physics     18 non-null     float64
#  2   Chemistry   20 non-null     int64
#  3   Math        18 non-null     float64
#  4   Bilogy      19 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 932.0 bytes
# None
#        Student_ID    Physics  Chemistry       Math     Bilogy
# count    20.00000  18.000000  20.000000  18.000000  19.000000
# mean     10.50000  47.555556  40.450000  41.944444  34.842105
# std       5.91608  24.127656  25.750779  31.912513  30.991510
# min       1.00000   9.000000   2.000000   1.000000   2.000000
# 25%       5.75000  23.750000  24.500000  14.000000   9.000000
# 50%      10.50000  50.500000  36.500000  35.000000  28.000000
# 75%      15.25000  64.500000  55.500000  73.750000  45.500000
# max      20.00000  92.000000  98.000000  94.000000  94.000000

# %% [markdown]
# 4. Show how many null values we have in each column.

# %%
print(df.isnull().sum())
# Out:
# Student_ID    0
# Physics       2
# Chemistry     0
# Math          2
# Bilogy        1
# dtype: int64

# %% [markdown]
# 5. Replace any column’s null values with the mean value of that particular column.

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %% [markdown]
# 6. Show only the Math scores of all the students.

# %%
print(df["Math"])
# Out:
# 0     85.000000
# 1     34.000000
# 2      2.000000
# 3      5.000000
# 4      1.000000
# 5     26.000000
# 6     45.000000
# 7     41.944444
# 8     38.000000
# 9     10.000000
# 10     4.000000
# 11    33.000000
# 12    74.000000
# 13    33.000000
# 14    73.000000
# 15    94.000000
# 16    41.944444
# 17    36.000000
# 18    75.000000
# 19    87.000000
# Name: Math, dtype: float64

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Generate a scatter plot graph for temperature_dhaka vs humidity_dhaka using (*) as the
# marker in color red.

# %%
temperature_dhaka = [25,34,21,45,28,6,43,18,7,2]
humidity_dhaka = [28,25,29,20,26,50,19,29,52,55]

plt.scatter(temperature_dhaka,
            humidity_dhaka,
            marker="*",
            color="red")
plt.xlabel("Temperature")
plt.ylabel("Humidity")

plt.show()

# %% [markdown]
# 2. Now do a line plot for study_hours vs marks with figure size (12,8)

# %%
study_hours = [2,3,4,4,5,6,7,7,8,9,9,10,11,11,12]
marks = [6,10,15,20,34,44,55,60,55,67,70,80,90,99,100]

plt.figure(figsize=(12,8))
plt.plot(study_hours,
         marks)
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# 3. Now draw a horizontal bar graph showing the scores in each of the subjects.

# %%
subjects = ['Maths','English','Science','Physics','Computer']
marks = [89,90,45,78,99]

plt.barh(subjects,marks)

plt.show()

# %% [markdown]
# 4. Draw a vertical bar graph where each subject score is visualized in different colors.

# %%
colors = ['red','blue','green','orange','purple']

plt.bar(subjects,
        marks,
        color=colors)

plt.show()

# %% [markdown]
# 5. Show all these graphs in one graph using subplot( ) function.

# %%
study_marks = [6,10,15,20,34,44,55,60,55,67,70,80,90,99,100]
subject_marks = [89,90,45,78,99]
plt.figure(figsize=(12,8))

# Scatter Plot
plt.subplot(2,2,1)
plt.scatter(temperature_dhaka, humidity_dhaka,
            marker='*', color='red')
plt.title("Scatter Plot")

# Line Plot
plt.subplot(2,2,2)
plt.plot(study_hours, study_marks)
plt.title("Line Plot")

# Horizontal Bar
plt.subplot(2,2,3)
plt.barh(subjects, subject_marks)
plt.title("Horizontal Bar")

# Vertical Bar
plt.subplot(2,2,4)
plt.bar(subjects, subject_marks, color=colors)
plt.title("Vertical Bar")

plt.tight_layout()
plt.show()
